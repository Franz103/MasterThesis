# %%
import numpy as np

# %%
loc, scale = 0., 1.
s = np.random.laplace(loc, scale, 1000)

# %%
import matplotlib.pyplot as plt
#count, bins, ignored = plt.hist(s, 30, density=True)
x = np.arange(-8., 8., .01)
df = np.exp(-abs(x-loc)/scale)/(2.*scale)
plt.plot(x, pdf)
# = (1/(scale * np.sqrt(2 * np.pi)) *
#    np.exp(-(x - loc)**2 / (2 * scale**2)))
#lt.plot(x,g)
plt.savefig('laplace_distribution.png')

# %%
import matplotlib.pyplot as plt
#count, bins, ignored = plt.hist(s, 30, density=True)
x = np.arange(-8., 8., .01)
#pdf = np.exp(-abs(x-loc)/scale)/(2.*scale)
#plt.plot(x, pdf)
g = (1/(scale * np.sqrt(2 * np.pi)) *
    np.exp(-(x - loc)**2 / (2 * scale**2)))
plt.plot(x,g)
plt.savefig('gaussian_distribution.png')

# %%
import math
math.log(0.2,21/36)
# Out:
# 2.9859895384224293

# %%
21/36
# Out:
# 0.5833333333333334

# %%
0.58*0.58*0.58
# Out:
# 0.19511199999999998
